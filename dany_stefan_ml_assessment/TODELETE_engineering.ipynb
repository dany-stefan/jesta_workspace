# %% [markdown]
# # Fashion Demand Forecasting - ML Engineering
#
# **Part 2: ML Engineering (Tasks 4-5)**
#
# **Author:** Dany Stefan
# **Date:** February 2026
#
# ---
#
# ## Overview
#
# This notebook demonstrates a complete ML engineering workflow for fashion retail demand forecasting:
# - Data ingestion and exploration
# - Data quality analysis and cleaning
# - Feature engineering
# - Model development and comparison
# - Evaluation and testing
#
# **Key Principles:**
# - Production-ready, maintainable code
# - Clear logic and reasoning
# - Proper validation methodology
# - Focus on what matters vs. what doesn't

# %% [markdown]
# ---
# ## 1. Data Ingestion & Setup
#
# **What matters:**
# - Using Polars (production requirement)
# - Understanding data structure and business context
# - Setting up reproducible environment
#
# **What doesn't:**
# - Fancy data loading techniques
# - Over-engineering simple data reads

# %%
# Import required libraries
# TODO: Add imports for Polars, sklearn, matplotlib, etc.

# %%
# Load data
# TODO: Load fashion_sample.csv using Polars

# %% [markdown]
# ---
# ## 2. Exploratory Data Analysis (EDA)
#
# **What matters:**
# - Understanding sales patterns and seasonality
# - Identifying stockout periods
# - Analyzing markdown impact on sales
# - Finding data quality issues
#
# **What doesn't:**
# - Exhaustive statistical tests
# - Perfect visualizations (insights > aesthetics)

# %%
# Basic data inspection
# TODO: Display shape, columns, dtypes, first/last rows

# %%
# Descriptive statistics
# TODO: Summary statistics for numerical columns

# %%
# Visualize sales over time
# TODO: Line plot of sales vs date

# %%
# Analyze inventory patterns
# TODO: Visualize inventory over time, identify stockouts

# %%
# Price analysis
# TODO: Track price changes, markdown periods, price elasticity

# %% [markdown]
# ---
# ## 3. Data Cleaning & Quality
#
# **What matters:**
# - Handling missing values appropriately
# - Dealing with stockout periods (can't sell what you don't have)
# - Preserving business logic (inventory constraints)
#
# **What doesn't:**
# - Over-cleaning (some noise is realistic)
# - Removing too much data

# %%
# Check for missing values
# TODO: Identify and analyze missing data

# %%
# Handle data quality issues
# TODO: Address missing values, anomalies, stockout periods

# %%
# Create clean dataset
# TODO: Finalize cleaned data

# %% [markdown]
# ---
# ## 4. Feature Engineering
#
# **What matters:**
# - Domain-relevant features (time since launch, days until stockout, markdown depth)
# - Price elasticity signals
# - Inventory constraints
# - Lag features for temporal patterns
#
# **What doesn't:**
# - Hundreds of features (curse of dimensionality with limited data)
# - Complex transformations without business justification

# %%
# Time-based features
# TODO: Day of week, days since launch, product age, etc.

# %%
# Pricing features
# TODO: Markdown percentage, price change, discount depth, etc.

# %%
# Inventory features
# TODO: Stock level, stockout indicators, restock events, etc.

# %%
# Lag features
# TODO: Previous day sales, rolling averages, trends, etc.

# %%
# Finalize feature set
# TODO: Combine all features, handle NaNs from rolling windows

# %% [markdown]
# ---
# ## 5. Train/Test Split
#
# **What matters:**
# - Time-based split (no data leakage!)
# - Representative test set
# - Handling the limited data problem (100 days)
#
# **What doesn't:**
# - Random splits (this is time series!)
# - Complex cross-validation with tiny dataset

# %%
# Time-based train/test split
# TODO: Split data chronologically, define train and test periods

# %%
# Prepare X and y
# TODO: Separate features and target variable

# %% [markdown]
# ---
# ## 6. Baseline Model
#
# **What matters:**
# - Simple, explainable benchmark
# - Establishes minimum acceptable performance
# - Fast to implement and validate
#
# **What doesn't:**
# - Optimizing the baseline (it's just a reference point)
# - Complex baseline models

# %%
# Baseline: Simple moving average or naive forecast
# TODO: Implement baseline model (e.g., 7-day moving average)

# %%
# Evaluate baseline
# TODO: Calculate WMAPE, MAE, RMSE for baseline

# %% [markdown]
# ---
# ## 7. Model Selection & Comparison
#
# **What matters:**
# - Models suitable for small datasets
# - Models that handle non-linear patterns
# - Interpretability for business stakeholders
# - Production feasibility (memory, speed)
#
# **What doesn't:**
# - Deep learning (not enough data)
# - Ensemble of 10+ models (over-engineering)

# %%
# Model 1: Linear Regression
# TODO: Train linear model, evaluate

# %%
# Model 2: Random Forest
# TODO: Train random forest, evaluate

# %%
# Model 3: Gradient Boosting (LightGBM or XGBoost)
# TODO: Train gradient boosting model, evaluate

# %% [markdown]
# ---
# ## 8. Model Training & Evaluation
#
# **What matters:**
# - Proper metrics (WMAPE matches production)
# - Error analysis (where/why does it fail?)
# - Feature importance (business insights)
#
# **What doesn't:**
# - Chasing perfect accuracy with 100 data points
# - Complex hyperparameter tuning (risk of overfitting)

# %%
# Define evaluation metrics
# TODO: WMAPE, MAE, RMSE functions

# %%
# Train best model on full training set
# TODO: Final training with best hyperparameters

# %%
# Evaluate on test set
# TODO: Calculate all metrics on test data

# %%
# Feature importance analysis
# TODO: Plot and interpret feature importances

# %% [markdown]
# ---
# ## 9. Results Comparison
#
# **What matters:**
# - Clear comparison across all models
# - Business-relevant metrics
# - Understanding trade-offs
#
# **What doesn't:**
# - Statistical significance tests (not enough data)
# - Minor decimal differences in accuracy

# %%
# Compare all models
# TODO: Create comparison table with metrics for all models

# %%
# Visualize predictions vs actuals
# TODO: Plot predictions from all models against actual values

# %% [markdown]
# ---
# ## 10. Final Testing & Validation
#
# **What matters:**
# - Testing on held-out data
# - Error analysis (when/why it fails)
# - Production readiness considerations
#
# **What doesn't:**
# - Perfect predictions on 100 days of data
# - Over-tuning for this specific product

# %%
# Final model selection
# TODO: Select best model based on metrics and business requirements

# %%
# Error analysis
# TODO: Analyze prediction errors, identify patterns in failures

# %%
# Production considerations
# TODO: Model size, inference time, memory usage analysis

# %% [markdown]
# ---
# ## 11. Key Findings & Recommendations
#
# **Summary of Results:**
# - [To be filled after analysis]
#
# **Key Insights:**
# - [To be filled after analysis]
#
# **Recommendations:**
# - [To be filled after analysis]
#
# **Next Steps:**
# - [To be filled after analysis]
